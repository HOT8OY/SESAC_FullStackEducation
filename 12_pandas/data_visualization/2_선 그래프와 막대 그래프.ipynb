# %% [markdown]
# # **선 그래프와 막대 그래프**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.rcParams["axes.unicode_minus"] = False
plt.rc("font", family="Malgun Gothic")

# %%
import pandas as pd

# %%
df=pd.read_csv("seoul_park.csv")
df.head()
# Out:
#    Unnamed: 0          날짜 요일 공휴일     날씨    어른    청소년  어린이  외국인   단체  총입장객수  \
# 0           0  2016-01-01  금   O  구름 조금  2799  141.0  419   47    0   4382
# 1           1  2016-01-02  토   O  구름 많음  4370  203.0  600  100  111   7265
# 2           2  2016-01-03  일   O  구름 많음  2571  128.0  309   91    0   4557
# 3           3  2016-01-04  월   X  구름 많음   602  463.0  235   51  223   1690
# 4           4  2016-01-05  화   X  구름 많음   319   35.0   62   43   47   1256
#
#       연  월  일       매출액
# 0  2016  1  1  33590000
# 1  2016  1  2  51730000
# 2  2016  1  3  30080000
# 3  2016  1  4   8900000
# 4  2016  1  5   4160000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1086 entries, 0 to 1085
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1086 non-null   int64
#  1   날짜          1086 non-null   object
#  2   요일          1086 non-null   object
#  3   공휴일         1086 non-null   object
#  4   날씨          939 non-null    object
#  5   어른          1086 non-null   int64
#  6   청소년         1086 non-null   float64
#  7   어린이         1086 non-null   int64
#  8   외국인         1086 non-null   int64
#  9   단체          1086 non-null   int64
#  10  총입장객수       1086 non-null   int64
#  11  연           1086 non-null   int64
#  12  월           1086 non-null   int64
#  13  일           1086 non-null   int64
#  14  매출액         1086 non-null   int64
# dtypes: float64(1), int64(10), object(4)
# memory usage: 127.4+ KB

# %% [markdown]
# ### 선 그래프
#
# #### 1-1. Matplotlib
#
# 월별 데이터 묶기(groupby() 사용)

# %%
# 월별 데이터 묶기
gb_mon = df.groupby("월")

# %%
df_mon = gb_mon.mean(numeric_only=True) # 숫자형 열만 평균을 계산한다.
df_mon
# Out:
#     Unnamed: 0           어른          청소년          어린이         외국인  \
# 월
# 1   557.333333   497.892473   140.623656    79.784946   17.978495
# 2   580.623529   978.129412   128.247059   150.552941   41.447059
# 3   605.814433  2957.432990   209.000000   386.350515   41.123711
# 4   403.833333  6811.033333   816.422222  1061.977778  104.411111
# 5   434.333333  7894.301075  1270.827957  1122.376344  149.505376
# 6   464.833333  5516.033333   849.855556   653.911111  129.033333
# 7   495.333333  1443.978495   290.827957   206.881720   79.258065
# 8   526.333333  1803.784946   254.086022   461.021505   80.870968
# 9   556.833333  5506.133333   314.833333   829.744444   94.033333
# 10  587.333333  6377.075269   782.774194  1165.892473  100.440860
# 11  617.833333  2068.011111   354.211111   339.711111   40.100000
# 12  699.696203   489.797468    85.658228    66.898734   18.746835
#
#              단체         총입장객수            연          일           매출액
# 월
# ...

# %%
# 어른, 어린이, 청소년별 월별 입장객수 선그래프로 보기
plt.title("서울대공원 입장객 분석", fontsize=20) # 그래프 제목
plt.plot(df_mon["어른"], label="어른")
plt.plot(df_mon["어린이"], label="어린이")
plt.plot(df_mon["청소년"], label="청소년")
plt.xlabel("월", fontsize=15) # X 축 라벨
plt.ylabel("입장객수", fontsize=15) # Y 축 라벨
plt.legend()    # 어떤 선이 어떤 이름인지 보여줌
plt.show()

# %%
# 어른, 어린이, 청소년별 월별 입장객수 선그래프로 보기
plt.title("서울대공원 입장객 분석", fontsize=20) # 그래프 제목
plt.plot(df_mon["어른"], label="어른")
plt.plot(df_mon["어린이"], label="어린이")
plt.plot(df_mon["청소년"], label="청소년")
plt.xlabel("월", fontsize=15)      # X 축 라벨
plt.ylabel("입장객수", fontsize=15) # Y 축 라벨
plt.legend()    # 어떤 선이 어떤 이름인지 보여줌
plt.xticks([mon for mon in range(1,13)]) # X 축 눈금 조절 : 1부터 12가 들어있는 리스트를 xticks에 전달
plt.show()

# %% [markdown]
# ### 선 그래프 모양 변경하기
#
# 1. 마커(marker) : 그래프의 데이터 포인트를 나타내는 작은 심볼
# 2. 선 모양(linestyle) : 선의 모양을 설정한다.
# 3. 색(color) : 그래프의 색을 설정
#
# - marker : 관련 내용은 `https://matplotlib.org/stable/api/markers_api.html`에서 확인 가능
# - linestyle : `https://matplotlib.org/stable/api/_as_gen/matplotlib.lines.Line2D.html#matplotlib.lines.Line2D.set_linestyle`
# - color : `https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html`

# %%
# 마커(marker) 설정
plt.title("서울대공원 입장객 분석", fontsize=20) # 그래프 제목

plt.plot(df_mon["어른"], marker=".", linestyle="-.", color="b", label="어른")
plt.plot(df_mon["어린이"], marker="o", linestyle="--", color="k", label="어린이")
plt.plot(df_mon["청소년"], marker="^", linestyle=":", color="r", label="청소년")

plt.xlabel("월", fontsize=15)
plt.ylabel("입장객수", fontsize=15)

plt.grid(True, axis="x") # x 축에만 격자 생성

plt.legend()
plt.xticks([mon for mon in range(1,13)])
plt.show()

# %% [markdown]
# ### seaborn
#
# data 매개변수에 시각화 하려는 데이터 프레임을 전달하고<br>
# x축과 y축에 들어갈 컬럼의 이름을 x, y 매개변수에 전달하여 간단하게 그래프를 그릴 수 있다.

# %%
sns.lineplot(data=df, x="월", y="어른", label="어른", errorbar=None)
# 기본 통계는 mean 이며, estimator='통계방식' 옵션을 통해 바꿀 수 있다.(min,max,sum 등)
# 시본은 통계 시각화 라이브러리이다. 집계 + 시각화를 한번에 처리함.
# 위 코드에서 시본은 내부적으로 -> df.groupby("월")["어른"].mean()

sns.lineplot(data=df, x="월", y="어린이", label="어린이", errorbar=None)
sns.lineplot(data=df, x="월", y="청소년", label="청소년", errorbar=None)
plt.ylabel("입장객수")
plt.xticks([mon for mon in range(1,13)])

plt.show()
df
# Out:
#       Unnamed: 0          날짜 요일 공휴일     날씨    어른    청소년  어린이  외국인   단체  총입장객수  \
# 0              0  2016-01-01  금   O  구름 조금  2799  141.0  419   47    0   4382
# 1              1  2016-01-02  토   O  구름 많음  4370  203.0  600  100  111   7265
# 2              2  2016-01-03  일   O  구름 많음  2571  128.0  309   91    0   4557
# 3              3  2016-01-04  월   X  구름 많음   602  463.0  235   51  223   1690
# 4              4  2016-01-05  화   X  구름 많음   319   35.0   62   43   47   1256
# ...          ...         ... ..  ..    ...   ...    ...  ...  ...  ...    ...
# 1081        1081  2019-03-27  수   X  구름 많음   464   10.0   30   21    0   1117
# 1082        1082  2019-03-28  목   X  구름 많음   687   46.0   28   35  108   1665
# 1083        1083  2019-03-29  금   X  구름 조금  1447  120.0   77   14  188   2870
# 1084        1084  2019-03-30  토   O     흐림  1326   44.0  169   29  115   2452
# 1085        1085  2019-03-31  일   O  구름 조금  2563  111.0  387   53    0   4418
#
#          연  월   일       매출액
# ...

# %% [markdown]
# ### 막대 그래프

# %% [markdown]
# #### Matplotlib를 사용한 막대 그래프

# %%
df_week = df.groupby("요일").mean(numeric_only=True)

df_week = df_week.reset_index() # '요일'열을 다시 데티터프레임의 열로 가져온다.
df
# Out:
#       Unnamed: 0          날짜 요일 공휴일     날씨    어른    청소년  어린이  외국인   단체  총입장객수  \
# 0              0  2016-01-01  금   O  구름 조금  2799  141.0  419   47    0   4382
# 1              1  2016-01-02  토   O  구름 많음  4370  203.0  600  100  111   7265
# 2              2  2016-01-03  일   O  구름 많음  2571  128.0  309   91    0   4557
# 3              3  2016-01-04  월   X  구름 많음   602  463.0  235   51  223   1690
# 4              4  2016-01-05  화   X  구름 많음   319   35.0   62   43   47   1256
# ...          ...         ... ..  ..    ...   ...    ...  ...  ...  ...    ...
# 1081        1081  2019-03-27  수   X  구름 많음   464   10.0   30   21    0   1117
# 1082        1082  2019-03-28  목   X  구름 많음   687   46.0   28   35  108   1665
# 1083        1083  2019-03-29  금   X  구름 조금  1447  120.0   77   14  188   2870
# 1084        1084  2019-03-30  토   O     흐림  1326   44.0  169   29  115   2452
# 1085        1085  2019-03-31  일   O  구름 조금  2563  111.0  387   53    0   4418
#
#          연  월   일       매출액
# ...

# %%
# 막대 그래프
plt.title("서울대공원 청소년 입장객 분석" , fontsize=20)
plt.bar(df_week["요일"], df_week["청소년"])
plt.xlabel("요일", fontsize=15)
plt.ylabel("청소년 입장객수", fontsize=15)
# Out:
# Text(0, 0.5, '청소년 입장객수')

# %%
# 가로 막대 그래프
plt.title("서울대공원 청소년 입장객 분석" , fontsize=20)
plt.barh(df_week["요일"], df_week["청소년"])    # bar -> barh로 변경
plt.xlabel("청소년 입장객수", fontsize=15)  # xlabel, ylabel의 내용을 가로에 맞게 변경
plt.ylabel("요일", fontsize=15)
# Out:
# Text(0, 0.5, '요일')

# %%
# 데이터 프레임 정렬 후 시각화
df_sorted = df_week.sort_values(by="청소년", ascending=False)

plt.title("서울대공원 청소년 입장객 분석")
plt.bar(df_sorted["요일"], df_sorted["청소년"])
plt.xlabel("요일")
plt.ylabel("청소년 입장객수")
# Out:
# Text(0, 0.5, '청소년 입장객수')

# %% [markdown]
# #### Seaborn을 사용한 막대 그래프

# %%
sns.barplot(data=df, x="요일", y="청소년", errorbar=None)
# Out:
# <Axes: xlabel='요일', ylabel='청소년'>

# %%
# 날씨별 어린이 입장객의 수를 막대그래프로
sns.barplot(data=df, x="날씨", y="어린이", errorbar=None)
# Out:
# <Axes: xlabel='날씨', ylabel='어린이'>

# %%
# "공휴일" 기준을 추가
sns.barplot(data=df, x="날씨", y="어린이", errorbar=None, hue="공휴일") # "공휴일" 값을 기준으로 그룹을 나눔
# Out:
# <Axes: xlabel='날씨', ylabel='어린이'>

# %% [markdown]
# ### 연도별 매출액 그래프 그리기
# 다음 조건을 모두 만족하도록 그래프를 그려보세요.
# - `plt.subplots`을 이용해 1행 2열로 구성된 서브플롯을 생성하여 `ax1`, `ax2`에 저장합니다.
# - `ax1`에는 x축을 `"연"`, y축을 `"매출액"`으로 하는 선 그래프를 그립니다. (`sns.lineplot` 사용)
#     - `errorbar=None`을 전달합니다.
#     - 마커는 `"o"`로 지정합니다.
#     - 색은 `"r"`로 지정합니다.
#     - `ax1`의 제목은 `"연도별 매출액"`으로 설정합니다.
# - `ax2`에는 x축을 `"연"`, y축을 `"매출액"`으로 하는 막대 그래프를 그립니다. (`sns.barplot` 사용)
#     - `errorbar=None`을 전달합니다.
#     - `hue`값을 이용하여 `"공휴일"`을 기준으로 그룹을 나눠 그립니다.
#     - `ax2`의 제목은 `"공휴일 여부에 따른 매출액"`으로 설정합니다.

# %%
fig, (ax1, ax2) = plt.subplots(1,2, constrained_layout=False)
sns.lineplot(data=df, x="연", y="매출액", errorbar=None, markers="o", color="r", ax=ax1)
ax1.set_title("연도별 매출액")

sns.barplot(data=df, x="연", y="매출액", errorbar=None, hue="공휴일", ax=ax2)
ax2.set_title("공휴일 여부에 따른 매출액")

plt.show()

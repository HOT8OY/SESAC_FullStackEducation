# %% [markdown]
# ### STT(Speech-to-Text)
# Whisper

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from openai import OpenAI

client = OpenAI()
# 오디오 파일은 텍스트가 아닌 바이너리 데이터이므로, 'rb'(Read Binary)모드로 열어서 전송해야 한다.
with open("output.mp3", "rb") as f:
    transcriptions = client.audio.transcriptions.create(
        model="whisper-1",
        file=f
    )
    print(transcriptions)
    print(transcriptions.text) # text만 뽑아올수도 있음.
# Out:
# Transcription(text='엔비디아가 내년 2월 중순 인공지능 AI 칩 H200 중국 수출을 시작한다고 로이터통신이 22일 보도했다. 로이터는 이 사안에 정통한 복수 관계자를 인용해 엔비디아가 기존 재고로 초기 주문에 대응할 계획이며 총 5,000얼만 개의 칩 모듈, H200 칩 약 4만 8만 개를 추라할 것으로 예측된다고 전했다. 또 해당 칩의 생산 능력을 확대할 계획은', logprobs=None, usage=UsageDuration(seconds=29.0, type='duration'))
# 엔비디아가 내년 2월 중순 인공지능 AI 칩 H200 중국 수출을 시작한다고 로이터통신이 22일 보도했다. 로이터는 이 사안에 정통한 복수 관계자를 인용해 엔비디아가 기존 재고로 초기 주문에 대응할 계획이며 총 5,000얼만 개의 칩 모듈, H200 칩 약 4만 8만 개를 추라할 것으로 예측된다고 전했다. 또 해당 칩의 생산 능력을 확대할 계획은
